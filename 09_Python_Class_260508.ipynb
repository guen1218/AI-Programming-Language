# %% [markdown]
# # 파이썬 클래스

# %%
class Circle:
    pi = 3.14
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return self.radius ** 2 * Circle.pi

c = Circle(2.5)
print(c.area())
# Out:
# 19.625

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height

rec = Rectangle(2.1, 3.4)
print(rec.area())
# Out:
# 7.14

# %%
class Account:
    def __init__(self):
        self.balance = 0
    def deposit(self, amount):
        self.balance += amount
    def withdraw(self, amount):
        self. balance -= amount
    
a1 = Account()
a1.deposit(100)
print(a1.balance)
# Out:
# 100

# %%
class Account:
    def __init__(self):
        self.__balance = 0
    def deposit(self,amount):
        self.__balance += amount
    def withdraw(self, amount):
        self.__balance -= amount
    def get_balance(self):
        return self.__balance

a2 = Account()
a2.deposit(50)

print("a2 : ", a2.get_balance())
# Out:
# a2 :  50

# %%
# 매직 매서드 연습
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return (f'{self.name}({self.age}쨜)')
    def __eq__(self, other):
        if self.name == other.name and self.age == other.age:
            return True
        return False

p1 = Person('홍길동', 15)
print(p1)

p2 = Person("홍길동", 15)
print(p2)

if p1 == p2 :
    print("오나지")
else :
    print("치가우")
# Out:
# 홍길동(15쨜)
# 홍길동(15쨜)
# 오나지

# %% [markdown]
# 학습 내용 되돌아보기 (1)
#
# 1. init 안에 self 넣기
#
# 2. this -> self

# %% [markdown]
# 학습 내용 되돌아보기 (2)
#
# _ _add_ _, _ _sub_ _
#
# 1. 8
#
# 2. 2

# %% [markdown]
# 학습 내용 되돌아보기(3)

# %%
class Student:
    def __init__(self, univ, name):
        self.univ = univ
        self.name = name
    def info(self):
        print(f"대학: {self.univ} 이름 : {self.name}")

student = Student("이성실", "한국대학교")
student.info()
# Out:
# 대학: 이성실 이름 : 한국대학교

# %% [markdown]
# 학습 내용 되돌아보기(4)

# %%
class Student:
    def __init__(self, name, dept, mid, final):
        self.name = name
        self.dept = dept
        self.mid = mid
        self.final = final
    
    def __str__(self):
        return f'학과 : {self.dept}, 이름: {self.name}, 중간: {self.mid}, 기말: {self.final}'
    
    def grade(self):
        if (st.mid+st.final)/2 >= 90 :
            return "A"
        elif (st.mid+st.final)/2 >= 80 :
            return "B"
        elif (st.mid+st.final)/2 >= 70 :
            return "C"
        elif (st.mid+st.final)/2 >= 60 :
            return "D"
        else:
            return "E"
st = Student("김경철", "기계학과", 89, 90)
print(st)

print(st.grade())
# Out:
# 학과 : 기계학과, 이름: 김경철, 중간: 89, 기말: 90
# B

# %% [markdown]
# 학습 내용 되돌아보기(5)

# %%
class Car:
    def __init__(self, giup, year, color):
        self.giup = giup
        self.year = year
        self.color = color
    
    def __str__(self):
        return f'자동차 회사: {self.giup}, 년식: {self.year}, 색상: {self.color}'

    def __eq__(self, value):
        if self.giup == value.giup and self.year == value.year and self.color == value.color:
            return True
        return False
    

mycar = Car('현대', 2020, '검정')
yourcar = Car('기아', 2021, '백색')

print(mycar)
print(yourcar)
print(mycar == yourcar)
# Out:
# 자동차 회사: 현대, 년식: 2020, 색상: 검정
# 자동차 회사: 기아, 년식: 2021, 색상: 백색
# False
