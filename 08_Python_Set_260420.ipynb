# %%
s1 = {1,2,3}
s1
# Out:
# {1, 2, 3}

# %%
s2 = set([1,2,3])
s2
# Out:
# {1, 2, 3}

# %%
s3 = {'a','b','c'}
s4 = set('abc')
s5 = set('Hello')
print(s3)
print(s4)
print(s5)
# Out:
# {'b', 'c', 'a'}
# {'b', 'c', 'a'}
# {'o', 'l', 'e', 'H'}

# %%
s6 = set([1, (2, 3)])
s6
# Out:
# {(2, 3), 1}

# %%
s10 = set()
s10.pop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 s10 = set()
# ----> 2 s10.pop()
#
# KeyError: 'pop from an empty set'

# %%
S = input().strip()
result = set()
for i in range(len(S)):
    sub_str = ''
    for j in range(i,len(S)):
        sub_str = sub_str+S[j]
        result.add(sub_str)

print(len(result))
# Out:
#  ababc
# 12

# %%
# import sys
# input = sys.stdin.readline
r = int(input()) # why not ?????????????????????????????????? what the value error? 
se = set()
for i in range(r):
    name, ac = input().split()
    if ac == 'enter':
        se.add(name)
    else :
        se.remove(name)
# ins = sorted(se, reverse=True)
# for j in ins :
#     print (j)

print("\n".join(sorted(se, reverse=True)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 3
#       1 # import sys
#       2 # input = sys.stdin.readline
# ----> 3 r = int(input()) # why not ?????????????????????????????????? what the value error?
#       4 se = set()
#       5 for i in range(r):
#
# ValueError: invalid literal for int() with base 10: ''
